# %% [markdown]
# ## Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data
df = pd.read_csv(r'C:\Users\javis\OneDrive\Documentos\Career Foundry\2. Data Immersion\6. Advanced Analytics\UK HPI Project\2. Data\2.1. Original Data\UK HPI.csv', index_col = False)

# %%
# Let's have a look at the dataframe
df.head()
# Out:
#          Date     RegionName   AreaCode  AveragePrice      Index  IndexSA  \
# 0  01/01/2004  Aberdeenshire  S12000034   81693.66964  40.864214      NaN
# 1  01/02/2004  Aberdeenshire  S12000034   81678.76231  40.856757      NaN
# 2  01/03/2004  Aberdeenshire  S12000034   83525.09702  41.780317      NaN
# 3  01/04/2004  Aberdeenshire  S12000034   84333.67900  42.184780      NaN
# 4  01/05/2004  Aberdeenshire  S12000034   86379.95396  43.208353      NaN
#
#    1m%Change  12m%Change  AveragePriceSA  SalesVolume  ...     NewPrice  \
# 0        NaN         NaN             NaN        388.0  ...  88436.13953
# 1  -0.018248         NaN             NaN        326.0  ...  88606.44649
# 2   2.260483         NaN             NaN        453.0  ...  90296.91375
# 3   0.968071         NaN             NaN        571.0  ...  90319.87844
# 4   2.426403         NaN             NaN        502.0  ...  91989.17763
#
#     NewIndex  New1m%Change  New12m%Change  NewSalesVolume     OldPrice  \
# ...

# %%
# We check also the bottom of the dataframe to make sure it is consistent
df.tail(10)
# Out:
#               Date                RegionName   AreaCode  AveragePrice  \
# 134819  01/03/2021  Yorkshire and The Humber  E12000003   183740.0294
# 134820  01/04/2021  Yorkshire and The Humber  E12000003   181022.1194
# 134821  01/05/2021  Yorkshire and The Humber  E12000003   183240.6693
# 134822  01/06/2021  Yorkshire and The Humber  E12000003   196242.4841
# 134823  01/07/2021  Yorkshire and The Humber  E12000003   180556.3417
# 134824  01/08/2021  Yorkshire and The Humber  E12000003   188016.4245
# 134825  01/09/2021  Yorkshire and The Humber  E12000003   196554.3779
# 134826  01/10/2021  Yorkshire and The Humber  E12000003   189337.9622
# 134827  01/11/2021  Yorkshire and The Humber  E12000003   193306.5814
# 134828  01/12/2021  Yorkshire and The Humber  E12000003   196876.8213
#
#              Index     IndexSA  1m%Change  12m%Change  AveragePriceSA  \
# 134819  134.935578  132.713558   1.152418   11.115252     180714.3334
# ...

# %%
# To find out the dimensions
df.shape
# Out:
# (134829, 54)

# %%
# To find out more basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134829 entries, 0 to 134828
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    134829 non-null  object
#  1   RegionName              134829 non-null  object
#  2   AreaCode                134829 non-null  object
#  3   AveragePrice            134829 non-null  float64
#  4   Index                   134829 non-null  float64
#  5   IndexSA                 4524 non-null    float64
#  6   1m%Change               134386 non-null  float64
#  7   12m%Change              129789 non-null  float64
#  8   AveragePriceSA          4524 non-null    float64
#  9   SalesVolume             130330 non-null  float64
#  10  DetachedPrice           128592 non-null  float64
#  11  DetachedIndex           128592 non-null  float64
#  12  Detached1m%Change       128183 non-null  float64
# ...

# %%
# To generate the descriptive statistics
df.describe()
# Out:
#        AveragePrice          Index      IndexSA      1m%Change     12m%Change  \
# count  1.348290e+05  134829.000000  4524.000000  134386.000000  129789.000000
# mean   1.659640e+05      80.321920    82.862964       0.575471       6.577532
# std    1.116970e+05      34.467742    31.658589       2.003514       8.980348
# min    2.712016e+03       1.096815    18.312610     -30.297781     -35.786566
# 25%    9.309390e+04      46.254770    56.218533      -0.432941       1.443454
# 50%    1.459236e+05      88.442346    89.836435       0.530798       5.535979
# 75%    2.081496e+05     105.411653   105.561134       1.526049      10.804786
# max    1.463378e+06     221.485238   151.111605      35.286646      98.437940
#
#        AveragePriceSA    SalesVolume  DetachedPrice  DetachedIndex  \
# count     4524.000000  130330.000000   1.285920e+05  128592.000000
# mean    156593.760033    1215.636285   2.923436e+05      81.741974
# ...

# %%
df= df.dropna(['NewIndex'])

# %%
# To check about missing values, we can check the frquency tables of the different variables.
# Firstly with the index, although being decimal numbers it will be very random and not too meaningful.
df['Index'].value_counts(dropna = False)
# Out:
# 100.000000    445
# 18.019533       9
# 22.002798       9
# 4.891206        6
# 18.218731       6
#              ...
# 140.458055      1
# 121.807646      1
# 39.323580       1
# 37.049841       1
# 123.056017      1
# Name: Index, Length: 130313, dtype: int64

# %%
# We try now with the Region
df['RegionName'].value_counts(dropna = False)
# Out:
# West Midlands Region       645
# Scotland                   645
# South West                 645
# United Kingdom             645
# England                    645
#                           ...
# Belfast                    204
# Ards and North Down        204
# Lisburn and Castlereagh    204
# Derry City and Strabane    204
# Fermanagh and Omagh        204
# Name: RegionName, Length: 421, dtype: int64

# %%
# Same for the Area Code
df['AreaCode'].value_counts(dropna = False)
# Out:
# E12000009    645
# N92000001    645
# W92000004    645
# E92000001    645
# E12000004    645
#             ...
# N09000002    204
# N09000011    204
# N09000010    204
# N09000005    204
# N09000004    204
# Name: AreaCode, Length: 421, dtype: int64

# %%
# And for the Date
df['Date'].value_counts(dropna = False)
# Out:
# 01/10/2021    421
# 01/06/2016    421
# 01/12/2012    421
# 01/10/2018    421
# 01/11/2012    421
#              ...
# 01/11/1975     10
# 01/04/1969     10
# 01/06/1981     10
# 01/06/1979     10
# 01/01/1977     10
# Name: Date, Length: 645, dtype: int64

# %%
# Sales volume
df['SalesVolume'].value_counts(dropna = False)
# Out:
# NaN        4499
# 157.0       520
# 140.0       516
# 144.0       515
# 148.0       507
#            ...
# 71075.0       1
# 90183.0       1
# 7058.0        1
# 6634.0        1
# 94748.0       1
# Name: SalesVolume, Length: 7386, dtype: int64

# %%
df['NewPrice'].value_counts(dropna = False)
# Out:
# NaN             6724
# 182717.40420       4
# 208421.66270       3
# 125967.98710       3
# 156844.16680       3
#                 ...
# 72645.01991        1
# 59319.99888        1
# 237564.68550       1
# 233454.66540       1
# 156193.85370       1
# Name: NewPrice, Length: 127961, dtype: int64

# %%
# Now let's rename a couple of columns, to make their names more intuitive
df.rename(columns = {'1m%Change':'%Change_AvgPrice_1month'},inplace = True)

# %%
df.rename(columns = {'12m%Change':'%Change_AvgPrice_12months'},inplace = True)

# %%
# To see the result
df.head()
# Out:
#          Date     RegionName   AreaCode  AveragePrice      Index  IndexSA  \
# 0  01/01/2004  Aberdeenshire  S12000034   81693.66964  40.864214      NaN
# 1  01/02/2004  Aberdeenshire  S12000034   81678.76231  40.856757      NaN
# 2  01/03/2004  Aberdeenshire  S12000034   83525.09702  41.780317      NaN
# 3  01/04/2004  Aberdeenshire  S12000034   84333.67900  42.184780      NaN
# 4  01/05/2004  Aberdeenshire  S12000034   86379.95396  43.208353      NaN
#
#    %Change_AvgPrice_1month  %Change_AvgPrice_12months  AveragePriceSA  \
# 0                      NaN                        NaN             NaN
# 1                -0.018248                        NaN             NaN
# 2                 2.260483                        NaN             NaN
# 3                 0.968071                        NaN             NaN
# 4                 2.426403                        NaN             NaN
#
#    SalesVolume  ...     NewPrice   NewIndex  New1m%Change  New12m%Change  \
# ...

# %%
# To export our result, firstly we create a path
path = r'C:\Users\javis\OneDrive\Documentos\Career Foundry\2. Data Immersion\6. Advanced Analytics\UK HPI Project'

# %%
# We export our dataframe as a csv file
df.to_csv(os.path.join(path, '2. Data','2.2. Prepared Data', 'HPI wrangled.csv'))
